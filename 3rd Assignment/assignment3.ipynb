# %% [markdown]
# # 3rd Assignment: SemEval 2025 Task 9 - The Food Hazard Detection Challenge
# > Markella Englezou, 8210039 <br />
# > Department of Management Science and Technology <br />
# > Athens University of Economics and Business <br />
# > t8210039@aueb.gr

# %% [markdown]
# *The Food Hazard Detection task evaluates explainable classification systems for titles of food-incident reports collected from the web. These algorithms may help automated crawlers find and extract food issues from web sources like social media in the future.*
#
# *The SemEval-Task combines two sub-tasks:*
# * *(ST1) Text classification for food hazard prediction, predicting the type of hazard and product.*
# * *(ST2) Food hazard and product "vector" detection, predicting the exact hazard and product.*
#
# *The task focuses on detecting the hazard and uses a two-step scoring metric based on the macro F1 score, focusing on the hazard label per sub-task.*
#
# *Explainability in food risk classification based on texts is currently underexplored although it may help humans quickly assess prediction validity and can be used for meta-learning approaches like clustering or pre-sorting examples. However, explanations can be diverse and task/model-dependent. Current literature includes both model-specific ([Assael et al., 2022](https://www.nature.com/articles/s41586-022-04448-z); [Pavlopoulos et al., 2022](https://aclanthology.org/2022.acl-long.259/)) and model agnostic ([Ribeiro et al., 2016](https://aclanthology.org/N16-3020/)) approaches. We aim to study mechanisms to explain decisions on food safety risks by asking participants to submit precise "vector"-labels (ST2) as explanations for their ST1 predictions.*
#
# *The complete challenge can be found [here](https://food-hazard-detection-semeval-2025.github.io/).*

# %% [markdown]
# # Prepare data and create necessary functions and classes.

# %% [markdown]
# * Install necessary libraries (uncomment if you need any).

# %%
# !pip install pandas numpy torch scikit-learn transformers transformers[torch]

# %% [markdown]
# * Import necessary libraries.

# %%
import pandas as pd
import numpy as np
import torch
import re
import os

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, classification_report
from transformers import RobertaTokenizer, RobertaForSequenceClassification, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader
from shutil import make_archive

# %% [markdown]
# * Download training, evaluation and testing data.

# %%
# !wget https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/refs/heads/main/data/incidents_train.csv
# !wget https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/refs/heads/main/data/incidents_valid.csv
# !wget https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/refs/heads/main/data/incidents_test.csv
# Out:
# --2025-02-13 10:10:39--  https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/refs/heads/main/data/incidents_train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12866710 (12M) [text/plain]
# Saving to: ‘incidents_train.csv’
#
# 100%[======================================>] 12,866,710  --.-K/s   in 0.05s
#
# 2025-02-13 10:10:39 (257 MB/s) - ‘incidents_train.csv’ saved [12866710/12866710]
#
# --2025-02-13 10:10:39--  https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/refs/heads/main/data/incidents_valid.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1369261 (1.3M) [text/plain]
# Saving to: ‘incidents_valid.csv’
#
# 100%[======================================>] 1,369,261   --.-K/s   in 0.007s
#
# 2025-02-13 10:10:39 (195 MB/s) - ‘incidents_valid.csv’ saved [1369261/1369261]
#
# --2025-02-13 10:10:39--  https://raw.githubusercontent.com/food-hazard-detection-semeval-2025/food-hazard-detection-semeval-2025.github.io/refs/heads/main/data/incidents_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2538599 (2.4M) [text/plain]
# Saving to: ‘incidents_test.csv’
#
# 100%[======================================>] 2,538,599   --.-K/s   in 0.01s
#
# 2025-02-13 10:10:39 (211 MB/s) - ‘incidents_test.csv’ saved [2538599/2538599]

# %% [markdown]
# * Read training, evaluation and testing data.

# %%
train_set = pd.read_csv('incidents_train.csv', index_col=0)
dev_set = pd.read_csv('incidents_valid.csv', index_col=0)
test_set = pd.read_csv('incidents_test.csv', index_col=0)

# %% [markdown]
# * Add function to compute final score by calculating the macro-F1-score on the participants’ predicted labels (hazards_pred & products_pred) using the annotated labels (hazards_true & products_true) as ground truth.
# * This function is given by the task organizers.

# %%
def compute_score(hazards_true, products_true, hazards_pred, products_pred):
  # Compute f1 for hazards:
  f1_hazards = f1_score(
    hazards_true,
    hazards_pred,
    average='macro'
  )

  # Compute f1 for products:
  f1_products = f1_score(
    products_true[hazards_pred == hazards_true],
    products_pred[hazards_pred == hazards_true],
    average='macro'
  )

  return (f1_hazards + f1_products) / 2.

# %% [markdown]
# * Preprocess text to train, validate and test the models.

# %%
# Combine title and text
train_set['combined_text'] = train_set['title'] + " " + train_set['text']
dev_set['combined_text'] = dev_set['title'] + " " + dev_set['text']
test_set['combined_text'] = test_set['title'] + " " + test_set['text']

# Preprocess text
def preprocess_text(text):
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'\b[A-Z]+-\d{3}-\d{2}\b', '', text)  # Remove patterns like FSIS-017-94
    text = re.sub(r'\b\d{3}-\d{2}\b', '', text)  # Remove patterns like 017-94
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    return text

# Preprocess train, dev and test sets
train_set['cleaned_text'] = train_set['combined_text'].apply(preprocess_text)
dev_set['cleaned_text'] = dev_set['combined_text'].apply(preprocess_text)
test_set['cleaned_text'] = test_set['combined_text'].apply(preprocess_text)

# %% [markdown]
# * Define a class as a custom dataset class for tokenizing text and preparing it for model training.
# * Parameters:
#     - texts: List of input texts.
#     - labels: Corresponding labels for each text.
#     - tokenizer: Pretrained tokenizer for processing text.
#     - max_len: Maximum sequence length for tokenization.

# %%
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        inputs = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )
        input_ids = inputs['input_ids'].squeeze()
        attention_mask = inputs['attention_mask'].squeeze()
        labels = torch.tensor(self.labels[idx], dtype=torch.float32 if isinstance(self.labels[idx], list) else torch.long)
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'labels': labels
        }

# %% [markdown]
# * Initialize RoBERTa tokenizer.

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-large')

# %% [markdown]
# * Create a training function for the RoBERTa models for sequence classification.
# * Parameters:
#     - texts: List of training input texts.
#     - labels: Corresponding labels for training texts.
#     - num_labels: Number of classification labels.
#     - val_texts: (Optional) List of validation input texts.
#     - val_labels: (Optional) Corresponding labels for validation texts.
#     - epochs: Number of training epochs (default: 5).
#     - batch_size: Training batch size (default: 16).
# * Returns:
#     - Trained RoBERTa model.

# %%
def train_roberta_model(texts, labels, num_labels, val_texts=None, val_labels=None, epochs=5, batch_size=16):
    train_dataset = TextDataset(texts, labels, tokenizer, max_len=128)
    val_dataset = TextDataset(val_texts, val_labels, tokenizer, max_len=128) if val_texts else None

    model = RobertaForSequenceClassification.from_pretrained('roberta-large', num_labels=num_labels)
    
    # Specify training arguments
    training_args = TrainingArguments(
        output_dir="./tmp",
        num_train_epochs=epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        logging_steps=10,
        eval_strategy="epoch",
        save_strategy="no",
        save_total_limit=0,
        weight_decay=0.02,
        learning_rate=3e-5,
        warmup_steps=500,
        fp16=True
    )
    
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset
    )
    
    trainer.train()
    return model

# %% [markdown]
# * Create a function that evaluates a trained model on a given dataloader.
# * Parameters:
#     - model: Trained model to be evaluated.
#     - dataloader: DataLoader containing the evaluation dataset.
#     - label_encoder: Encoder to transform numeric labels back to original string labels.
# * Returns:
#     - predicted_labels: List of predicted labels in their original form.
#     - gold_labels: List of ground truth labels in their original form.

# %%
def evaluate_model_with_dataloader(model, dataloader, label_encoder):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    total_predictions = []
    total_labels = []

    with torch.no_grad():
        for batch in dataloader:
            # Move batch to the same device as the model
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            logits = outputs.logits

            # Get predictions
            predictions = torch.argmax(logits, dim=-1)
            total_predictions.extend(predictions.cpu().numpy())
            total_labels.extend(labels.cpu().numpy())

    # Convert predictions and labels back to original string labels
    predicted_labels = label_encoder.inverse_transform(total_predictions)
    gold_labels = label_encoder.inverse_transform(total_labels)

    # Print classification report
    print(classification_report(gold_labels, predicted_labels, zero_division=0))

    return predicted_labels, gold_labels

# %% [markdown]
# * Create a function that makes predictions using a trained model on a list of input texts.
# * Parameters:
#     - texts: List of input texts to classify.
#     - model: Trained model for prediction.
#     - label_encoder: Encoder to transform numerical predictions back to string labels.
#     - tokenizer: Pretrained tokenizer to process the input texts.
# * Returns:
#     - List of predicted labels in their original string format.

# %%
def predict(texts, model, label_encoder, tokenizer):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    # Tokenize the input texts
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")
    inputs = {key: value.to(device) for key, value in inputs.items()} 

    # Make predictions
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=-1)

    # Decode predictions back to string labels
    return label_encoder.inverse_transform(predictions.cpu().numpy().tolist())

# %% [markdown]
# # ST1: Text classification for food hazard prediction, predicting the type of hazard and product

# %% [markdown]
# ## Encode labels and train the models

# %% [markdown]
# * Encode hazard category and product category labels.

# %%
# Encode labels
label_encoder_hazard_category = LabelEncoder()
label_encoder_product_category = LabelEncoder()

# Fit Transform train set
train_set['hazard_category_encoded'] = label_encoder_hazard_category.fit_transform(train_set['hazard-category'])
train_set['product_category_encoded'] = label_encoder_product_category.fit_transform(train_set['product-category'])

# Transform dev and test sets
dev_set['hazard_category_encoded'] = label_encoder_hazard_category.transform(dev_set['hazard-category'])
dev_set['product_category_encoded'] = label_encoder_product_category.transform(dev_set['product-category'])

test_set['hazard_category_encoded'] = label_encoder_hazard_category.transform(test_set['hazard-category'])
test_set['product_category_encoded'] = label_encoder_product_category.transform(test_set['product-category'])

# %% [markdown]
# * Train a model to predict the hazard categories.
# * Arguments:
#     - Training input texts.
#     - Corresponding encoded labels.
#     - Number of unique hazard categories.
#     - Validation input texts.
#     - Corresponding validation labels.
#     - Number of epochs (3).

# %%
hazard_category_model = train_roberta_model(
    train_set['cleaned_text'].tolist(),
    train_set['hazard_category_encoded'].tolist(),
    num_labels=len(label_encoder_hazard_category.classes_),
    val_texts=dev_set['cleaned_text'].tolist(),
    val_labels=dev_set['hazard_category_encoded'].tolist(),
    epochs=3
)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='954' max='954' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [954/954 03:30, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.202500</td>
#       <td>0.342965</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.344800</td>
#       <td>0.279363</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.139400</td>
#       <td>0.274214</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# * Train a model to predict the product categories.
# * Arguments:
#     - Training input texts.
#     - Corresponding encoded labels.
#     - Number of unique product categories.
#     - Validation input texts.
#     - Corresponding validation labels.
#     - Number of epochs (4).

# %%
product_category_model = train_roberta_model(
    train_set['cleaned_text'].tolist(),
    train_set['product_category_encoded'].tolist(),
    num_labels=len(label_encoder_product_category.classes_),
    val_texts=dev_set['cleaned_text'].tolist(),
    val_labels=dev_set['product_category_encoded'].tolist(),
    epochs=4
)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='1272' max='1272' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1272/1272 04:40, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.779600</td>
#       <td>1.046289</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.738600</td>
#       <td>0.896073</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.525600</td>
#       <td>0.806444</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.302400</td>
#       <td>0.793801</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Evaluate the hazard category model

# %% [markdown]
# * Evaluate the model based on the validation data and add predictions to the dev_set.

# %%
# Define a DataLoader for the development set
dev_dataset_hazard_category = TextDataset(
    dev_set['cleaned_text'].tolist(),
    dev_set['hazard_category_encoded'].tolist(),
    tokenizer,
    max_len=128
)

dev_dataloader_hazard_category = DataLoader(dev_dataset_hazard_category, batch_size=8, shuffle=False)

# Evaluate the hazard model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    hazard_category_model, dev_dataloader_hazard_category, label_encoder_hazard_category
)

# Store predictions in the dev_set DataFrame
dev_set['predictions-hazard-category'] = predicted_labels
# Out:
#                                 precision    recall  f1-score   support
#
#                      allergens       0.94      0.98      0.96       207
#                     biological       0.96      0.99      0.97       194
#                       chemical       0.88      0.82      0.85        28
# food additives and flavourings       1.00      0.50      0.67         2
#                 foreign bodies       0.98      0.94      0.96        63
#                          fraud       0.91      0.71      0.79        41
#           organoleptic aspects       0.70      0.88      0.78         8
#                   other hazard       0.82      0.64      0.72        14
#               packaging defect       0.62      0.62      0.62         8
#
#                       accuracy                           0.94       565
#                      macro avg       0.87      0.79      0.81       565
#                   weighted avg       0.94      0.94      0.93       565

# %% [markdown]
# * Evaluate the model based on the test data and add predictions to the test_set.

# %%
# Define a DataLoader for the test set
test_dataset_hazard_category = TextDataset(
    test_set['cleaned_text'].tolist(),
    test_set['hazard_category_encoded'].tolist(),
    tokenizer,
    max_len=128
)

test_dataloader_hazard_category = DataLoader(test_dataset_hazard_category, batch_size=8, shuffle=False)

# Evaluate the hazard model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    hazard_category_model, test_dataloader_hazard_category, label_encoder_hazard_category
)

# Store predictions in the test_set DataFrame
test_set['predictions-hazard-category'] = predicted_labels
# Out:
#                                 precision    recall  f1-score   support
#
#                      allergens       0.96      0.96      0.96       365
#                     biological       0.98      0.97      0.98       343
#                       chemical       0.98      0.90      0.94        52
# food additives and flavourings       1.00      0.50      0.67         4
#                 foreign bodies       0.96      0.97      0.97       111
#                          fraud       0.77      0.79      0.78        75
#                      migration       0.00      0.00      0.00         1
#           organoleptic aspects       0.83      1.00      0.91        10
#                   other hazard       0.66      0.81      0.72        26
#               packaging defect       0.82      0.90      0.86        10
#
#                       accuracy                           0.94       997
#                      macro avg       0.80      0.78      0.78       997
#                   weighted avg       0.94      0.94      0.94       997

# %% [markdown]
# ## Evaluate the product category model

# %% [markdown]
# * Evaluate the model based on the validation data and add predictions to the dev_set.

# %%
# Define a DataLoader for the development set
dev_dataset_product_category = TextDataset(
    dev_set['cleaned_text'].tolist(),
    dev_set['product_category_encoded'].tolist(),
    tokenizer,
    max_len=128
)

dev_dataloader_product_category = DataLoader(dev_dataset_product_category, batch_size=8, shuffle=False)

# Evaluate the product model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    product_category_model, dev_dataloader_product_category, label_encoder_product_category
)

# Store predictions in the dev_set DataFrame
dev_set['predictions-product-category'] = predicted_labels
# Out:
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.88      1.00      0.93         7
#                       cereals and bakery products       0.84      0.76      0.80        75
#      cocoa and cocoa preparations, coffee and tea       0.50      0.73      0.59        15
#                                     confectionery       0.72      0.50      0.59        26
# dietetic foods, food supplements, fortified foods       0.58      0.79      0.67        14
#                                     fats and oils       1.00      0.75      0.86         4
#                                    feed materials       0.00      0.00      0.00         1
#                             fruits and vegetables       0.73      0.79      0.76        52
#                                  herbs and spices       0.73      0.84      0.78        19
#                                 ices and desserts       0.88      0.88      0.88        24
#                      meat, egg and dairy products       0.89      0.92      0.91       146
#                           non-alcoholic beverages       0.85      0.89      0.87        19
#                      nuts, nut products and seeds       0.88      0.91      0.90        33
#                        other food product / mixed       1.00      0.20      0.33        10
#                                          pet feed       0.33      1.00      0.50         1
#                        prepared dishes and snacks       0.57      0.57      0.57        56
#                                           seafood       0.96      0.89      0.92        27
#              soups, broths, sauces and condiments       0.86      0.83      0.85        36
#
#                                          accuracy                           0.80       565
#                                         macro avg       0.73      0.74      0.71       565
#                                      weighted avg       0.81      0.80      0.79       565

# %% [markdown]
# * Evaluate the model based on the test data and add predictions to the test_set.

# %%
# Define a DataLoader for the test set
test_dataset_product_category = TextDataset(
    test_set['cleaned_text'].tolist(),
    test_set['product_category_encoded'].tolist(),
    tokenizer,
    max_len=128
)

test_dataloader_product_category = DataLoader(test_dataset_product_category, batch_size=8, shuffle=False)

# Evaluate the product model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    product_category_model, test_dataloader_product_category, label_encoder_product_category
)

# Store predictions in the test_set DataFrame
test_set['predictions-product-category'] = predicted_labels
# Out:
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       1.00      0.94      0.97        16
#                       cereals and bakery products       0.84      0.78      0.81       121
#      cocoa and cocoa preparations, coffee and tea       0.85      0.93      0.89        42
#                                     confectionery       0.72      0.79      0.75        33
# dietetic foods, food supplements, fortified foods       0.69      0.77      0.73        26
#                                     fats and oils       1.00      0.83      0.91         6
#                    food additives and flavourings       1.00      0.25      0.40         4
#                             fruits and vegetables       0.82      0.82      0.82       103
#                                  herbs and spices       0.64      0.80      0.71        20
#                             honey and royal jelly       1.00      0.50      0.67         2
#                                 ices and desserts       0.98      0.94      0.96        49
#                      meat, egg and dairy products       0.92      0.92      0.92       282
#                           non-alcoholic beverages       0.80      0.84      0.82        19
#                      nuts, nut products and seeds       0.82      0.87      0.85        54
#                        other food product / mixed       0.67      0.15      0.25        13
#                                          pet feed       1.00      1.00      1.00         2
#                        prepared dishes and snacks       0.62      0.62      0.62        92
#                                           seafood       0.92      0.95      0.93        60
#              soups, broths, sauces and condiments       0.77      0.88      0.82        52
#                                 sugars and syrups       0.00      0.00      0.00         1
#
#                                          accuracy                           0.84       997
#                                         macro avg       0.80      0.73      0.74       997
#                                      weighted avg       0.84      0.84      0.83       997

# %% [markdown]
# # ST2: Food hazard and product “vector” detection, predicting the exact hazard and product

# %% [markdown]
# ## Encode labels and train the models

# %% [markdown]
# * Encode hazard and product labels.

# %%
# Encode labels
label_encoder_hazard = LabelEncoder()
label_encoder_product = LabelEncoder()

# Fit Transform train set
train_set['hazard_encoded'] = label_encoder_hazard.fit_transform(train_set['hazard'])
train_set['product_encoded'] = label_encoder_product.fit_transform(train_set['product'])

# Add an "unknown" class to the label encoder
label_encoder_product.classes_ = np.append(label_encoder_product.classes_, 'unknown')

# Function to handle unseen categories
def encode_with_unknown(encoder, column):
    return [encoder.transform([x])[0] if x in encoder.classes_ else encoder.transform(['unknown'])[0] for x in column]

# Transform dev and test sets with handling for unseen categories
dev_set['hazard_encoded'] = encode_with_unknown(label_encoder_hazard, dev_set['hazard'])
dev_set['product_encoded'] = encode_with_unknown(label_encoder_product, dev_set['product'])

test_set['hazard_encoded'] = encode_with_unknown(label_encoder_hazard, test_set['hazard'])
test_set['product_encoded'] = encode_with_unknown(label_encoder_product, test_set['product'])

# %% [markdown]
# * Train a model to predict the hazards.
# * Arguments:
#     - Training input texts.
#     - Corresponding encoded labels.
#     - Number of unique hazards.
#     - Validation input texts.
#     - Corresponding validation labels.
#     - Number of epochs (7).
#     - Batch size (32).

# %%
hazard_model = train_roberta_model(
    train_set['cleaned_text'].tolist(),
    train_set['hazard_encoded'].tolist(),
    num_labels=len(label_encoder_hazard.classes_),
    val_texts=dev_set['cleaned_text'].tolist(),
    val_labels=dev_set['hazard_encoded'].tolist(),
    epochs=7,
    batch_size=32
)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='1113' max='1113' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1113/1113 06:24, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.228500</td>
#       <td>2.582979</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.198000</td>
#       <td>1.112550</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.833200</td>
#       <td>0.885747</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.636600</td>
#       <td>0.732694</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.671700</td>
#       <td>0.696913</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.326700</td>
#       <td>0.653181</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.321500</td>
#       <td>0.629650</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# * Train a model to predict the products.
# * Arguments:
#     - Training input texts.
#     - Corresponding encoded labels.
#     - Number of unique products.
#     - Validation input texts.
#     - Corresponding validation labels.
#     - Number of epochs (10).
#     - Batch size (32).

# %%
product_model = train_roberta_model(
    train_set['cleaned_text'].tolist(),
    train_set['product_encoded'].tolist(),
    num_labels=len(label_encoder_product.classes_),
    val_texts=dev_set['cleaned_text'].tolist(),
    val_labels=dev_set['product_encoded'].tolist(),
    epochs=10,
    batch_size=32
)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='1590' max='1590' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1590/1590 09:07, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.680800</td>
#       <td>6.544946</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.645500</td>
#       <td>5.475710</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.763400</td>
#       <td>4.476463</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.950400</td>
#       <td>3.983412</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.414200</td>
#       <td>3.710415</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.168700</td>
#       <td>3.497015</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.547300</td>
#       <td>3.409290</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.337700</td>
#       <td>3.286588</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.029100</td>
#       <td>3.255643</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.927200</td>
#       <td>3.241041</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Evaluate the hazard model

# %% [markdown]
# * Evaluate the model based on the validation data and add predictions to the dev_set.

# %%
# Define a DataLoader for the development set
dev_dataset_hazard = TextDataset(
    dev_set['cleaned_text'].tolist(),
    dev_set['hazard_encoded'].tolist(),
    tokenizer,
    max_len=128
)

dev_dataloader_hazard = DataLoader(dev_dataset_hazard, batch_size=8, shuffle=False)

# Evaluate the hazard model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    hazard_model, dev_dataloader_hazard, label_encoder_hazard
)

# Store predictions in the dev_set DataFrame
dev_set['predictions-hazard'] = predicted_labels
# Out:
#                                                  precision    recall  f1-score   support
#
#                                       Aflatoxin       1.00      1.00      1.00         1
#                                  abnormal smell       0.00      0.00      0.00         1
#                                       allergens       0.00      0.00      0.00         1
#                                          almond       1.00      0.86      0.92         7
#                          antibiotics, vet drugs       0.00      0.00      0.00         1
#                                   bacillus spp.       1.00      1.00      1.00         2
#                            bad smell / off odor       0.50      1.00      0.67         1
#                                   bone fragment       1.00      1.00      1.00         1
#                                      brazil nut       0.00      0.00      0.00         1
#                               bulging packaging       1.00      0.67      0.80         3
#                                          cashew       1.00      1.00      1.00         3
#                     celery and products thereof       1.00      1.00      1.00         1
#                                         cereals       0.00      0.00      0.00         1
#  cereals containing gluten and products thereof       0.91      0.87      0.89        23
#                                        chemical       0.00      0.00      0.00         1
#                chemical compound (high content)       1.00      1.00      1.00         1
#                chemical compound (unauthorised)       0.33      1.00      0.50         1
#                           clostridium botulinum       0.80      1.00      0.89         4
#                                       coliforms       1.00      1.00      1.00         1
#                                 cronobacter spp       0.00      0.00      0.00         1
#                crustaceans and products thereof       0.50      0.50      0.50         2
#                                      cyclospora       1.00      1.00      1.00         1
#                               damaged packaging       0.00      0.00      0.00         1
#                     e 425 - konjac unauthorised       1.00      1.00      1.00         1
#                       eggs and products thereof       0.91      0.87      0.89        23
#                                   enteroviruses       0.00      0.00      0.00         1
#                                escherichia coli       0.82      1.00      0.90        27
#                       fish and products thereof       0.83      1.00      0.91         5
#                                  foreign bodies       0.33      0.33      0.33         3
#                                  glass fragment       1.00      1.00      1.00        10
#                                        hazelnut       1.00      1.00      1.00         2
#                                    heavy metals       1.00      1.00      1.00         3
#                         high content of cyanide       0.00      0.00      0.00         1
#                             improper conditions       1.00      1.00      1.00         2
#                              improper packaging       0.00      0.00      0.00         1
#                              incorrect labeling       0.33      0.50      0.40         4
#                          incorrect use by dates       0.50      0.67      0.57         3
#                                         insects       0.67      1.00      0.80         2
#                               inspection issues       0.92      1.00      0.96        11
#            insufficient labelling/documentation       0.00      0.00      0.00         2
#                        labelling/misdescription       1.00      0.75      0.86         4
#                          listeria monocytogenes       0.97      1.00      0.99        74
#                                    listeria spp       0.00      0.00      0.00         1
#                                  metal fragment       0.88      0.82      0.85        17
#                   microbiological contamination       0.50      0.50      0.50         2
#                       milk and products thereof       0.93      0.95      0.94        65
#                                     misbranding       1.00      0.50      0.67         2
#                                  misdescription       0.00      0.00      0.00         3
#                                     mislabelled       0.00      0.00      0.00         1
#                                          moulds       0.75      1.00      0.86         3
#                    mustard and products thereof       1.00      0.80      0.89         5
#                                       norovirus       1.00      1.00      1.00         2
#                                            nuts       0.67      0.67      0.67         3
#                                           other       0.50      0.45      0.48        11
#                            other not classified       0.00      0.00      0.00         4
#         other not classified biological hazards       0.50      1.00      0.67         1
#           other not classified chemical hazards       0.67      0.67      0.67         3
# other not classified hazards for foreign bodies       0.00      0.00      0.00         1
#                                packaging defect       0.40      0.67      0.50         3
#                             pathogenic bacteria       0.00      0.00      0.00         1
#                                         patulin       1.00      1.00      1.00         1
#                    peanuts and products thereof       0.85      0.92      0.88        24
#                                       pecan nut       1.00      1.00      1.00         2
#                                  pieces of wood       0.00      0.00      0.00         1
#                                   pistachio nut       0.33      1.00      0.50         1
#                                plastic fragment       0.88      1.00      0.94        23
#                polycyclic aromatic hydrocarbons       1.00      1.00      1.00         1
#                             poor hygienic state       1.00      1.00      1.00         1
#                   poor or insufficient controls       0.00      0.00      0.00         1
#                                      processing       1.00      1.00      1.00         4
#                                pseudomonas spp.       1.00      1.00      1.00         1
#                                rubber fragments       1.00      1.00      1.00         3
#                                      salmonella       0.99      1.00      0.99        69
#               sesame seeds and products thereof       0.75      0.60      0.67         5
#                   soybeans and products thereof       0.78      0.95      0.86        19
#                   specified risk material (srm)       1.00      1.00      1.00         1
#                                        spoilage       1.00      1.00      1.00         4
#                                  staphylococcus       1.00      1.00      1.00         1
#                                          stones       1.00      1.00      1.00         1
#                             sulphates/sulphites       0.00      0.00      0.00         1
#                                 sulphur dioxide       1.00      1.00      1.00         2
#                   sulphur dioxide and sulphites       0.85      1.00      0.92        11
#                               taste disturbance       0.50      1.00      0.67         1
#  too high content of tetrahydrocannabinol (THC)       1.00      1.00      1.00         1
#                                           toxin       1.00      0.50      0.67         2
#                     unauthorised colour sudan 4       1.00      1.00      1.00         1
#                             unauthorised import       1.00      1.00      1.00         1
#              unauthorised placing on the market       0.00      0.00      0.00         1
#           unauthorised substance ethylene oxide       1.00      1.00      1.00         6
#                             undeclared additive       1.00      1.00      1.00         2
#                          undeclared constituent       0.00      0.00      0.00         1
#                                          walnut       1.00      0.75      0.86         4
#                                          yeasts       0.00      0.00      0.00         1
#
#                                        accuracy                           0.88       565
#                                       macro avg       0.63      0.66      0.64       565
#                                    weighted avg       0.85      0.88      0.86       565

# %% [markdown]
# * Evaluate the model based on the test data and add predictions to the test_set.

# %%
# Define a DataLoader for the test set
test_dataset_hazard = TextDataset(
    test_set['cleaned_text'].tolist(),
    test_set['hazard_encoded'].tolist(),
    tokenizer,
    max_len=128
)

test_dataloader_hazard = DataLoader(test_dataset_hazard, batch_size=8, shuffle=False)

# Evaluate the hazard model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    hazard_model, test_dataloader_hazard, label_encoder_hazard
)

# Store predictions in the test_set DataFrame
test_set['predictions-hazard'] = predicted_labels
# Out:
#                                                  precision    recall  f1-score   support
#
#                                       Aflatoxin       1.00      1.00      1.00         2
#                                  abnormal smell       0.00      0.00      0.00         1
#                                 alcohol content       0.00      0.00      0.00         1
#                                       alkaloids       1.00      1.00      1.00         1
#                                       allergens       0.00      0.00      0.00         3
#                                          almond       0.92      0.92      0.92        13
#                                       amygdalin       0.00      0.00      0.00         1
#                          antibiotics, vet drugs       0.00      0.00      0.00         1
#                                   bacillus spp.       1.00      1.00      1.00         3
#                            bad smell / off odor       1.00      1.00      1.00         1
#                                   bone fragment       1.00      1.00      1.00         2
#                                      brazil nut       0.00      0.00      0.00         1
#                               bulging packaging       0.50      0.75      0.60         4
#                                          cashew       0.71      0.83      0.77         6
#                     celery and products thereof       0.00      0.00      0.00         1
#                                         cereals       0.00      0.00      0.00         1
#  cereals containing gluten and products thereof       0.87      0.80      0.84        41
#                                        chemical       0.00      0.00      0.00         1
#                chemical compound (high content)       0.00      0.00      0.00         2
#                chemical compound (unauthorised)       0.33      0.50      0.40         2
#                           clostridium botulinum       1.00      0.62      0.77         8
#                                       coliforms       1.00      1.00      1.00         1
#                         compositional deviation       0.00      0.00      0.00         1
#                                 cronobacter spp       1.00      1.00      1.00         1
#                crustaceans and products thereof       0.67      0.67      0.67         3
#                                      cyclospora       1.00      1.00      1.00         2
#                               damaged packaging       0.00      0.00      0.00         1
#                     e 425 - konjac unauthorised       1.00      1.00      1.00         2
#                       eggs and products thereof       0.89      0.83      0.86        41
#                                   enteroviruses       1.00      1.00      1.00         2
#                                escherichia coli       0.87      1.00      0.93        47
#                          false marketing claims       0.00      0.00      0.00         1
#                       fish and products thereof       0.58      0.88      0.70         8
#                                  foreign bodies       0.17      0.20      0.18         5
#                                  glass fragment       1.00      0.88      0.94        17
#                                        hazelnut       1.00      1.00      1.00         3
#                                    heavy metals       1.00      0.83      0.91         6
#                          high content of copper       1.00      1.00      1.00         1
#                         high content of cyanide       0.67      1.00      0.80         2
#                        high content of vitamins       1.00      1.00      1.00         1
#                             improper conditions       0.50      0.33      0.40         3
#                              improper packaging       0.00      0.00      0.00         1
#                              incorrect labeling       0.25      0.38      0.30         8
#                          incorrect use by dates       0.71      1.00      0.83         5
#                                         insects       1.00      1.00      1.00         4
#                               inspection issues       0.74      1.00      0.85        20
#            insufficient labelling/documentation       0.00      0.00      0.00         4
#                        labelling/misdescription       0.36      0.57      0.44         7
#                          listeria monocytogenes       0.97      0.95      0.96       131
#                                    listeria spp       0.00      0.00      0.00         1
#                                  metal fragment       0.90      0.87      0.89        31
#                   microbiological contamination       0.67      0.67      0.67         3
#                       milk and products thereof       0.94      0.95      0.94       115
#                                     misbranding       0.33      0.33      0.33         3
#                                  misdescription       0.00      0.00      0.00         5
#                                     mislabelled       0.00      0.00      0.00         1
#                   molluscs and products thereof       0.00      0.00      0.00         1
#                                          moulds       1.00      1.00      1.00         5
#                    mustard and products thereof       0.89      0.80      0.84        10
#                       non compliance with HACCP       0.00      0.00      0.00         1
#                                       norovirus       1.00      1.00      1.00         4
#                                      novel food       0.00      0.00      0.00         1
#                                            nuts       0.67      0.33      0.44         6
#                                           other       0.33      0.53      0.41        19
#                        other misbranding issues       0.00      0.00      0.00         1
#                            other not classified       0.71      0.71      0.71         7
#         other not classified biological hazards       0.00      0.00      0.00         3
#           other not classified chemical hazards       0.80      1.00      0.89         4
# other not classified hazards for foreign bodies       0.00      0.00      0.00         2
#                                packaging defect       0.29      0.50      0.36         4
#                                            pahs       1.00      1.00      1.00         1
#      paralytic shellfish poisoning (psp) toxins       0.00      0.00      0.00         1
#                             pathogenic bacteria       0.00      0.00      0.00         1
#                                         patulin       1.00      1.00      1.00         2
#                    peanuts and products thereof       0.91      0.93      0.92        42
#                                       pecan nut       0.40      0.67      0.50         3
#                                  pieces of wood       1.00      1.00      1.00         1
#                                   pistachio nut       1.00      1.00      1.00         2
#                                plastic fragment       0.84      0.93      0.88        40
#                polycyclic aromatic hydrocarbons       1.00      1.00      1.00         1
#                             poor hygienic state       0.00      0.00      0.00         1
#                   poor or insufficient controls       0.00      0.00      0.00         2
#                                      processing       0.53      1.00      0.70         8
#                product category/characteristics       0.00      0.00      0.00         1
#                                pseudomonas spp.       1.00      1.00      1.00         1
#                                rubber fragments       1.00      1.00      1.00         6
#                                      salmonella       1.00      0.97      0.98       122
#               sesame seeds and products thereof       0.89      1.00      0.94         8
#                   soybeans and products thereof       0.86      0.74      0.79        34
#                   specified risk material (srm)       0.50      0.50      0.50         2
#                                        spoilage       0.86      1.00      0.92         6
#                                  staphylococcus       1.00      1.00      1.00         2
#                                          stones       1.00      1.00      1.00         2
#                             sulphates/sulphites       0.00      0.00      0.00         2
#                                 sulphur dioxide       0.75      1.00      0.86         3
#                   sulphur dioxide and sulphites       0.65      0.94      0.77        18
#                               taste disturbance       0.50      1.00      0.67         1
#  too high content of tetrahydrocannabinol (THC)       1.00      1.00      1.00         1
#                                           toxin       1.00      0.75      0.86         4
#                     unauthorised colour sudan 4       1.00      1.00      1.00         1
#                             unauthorised import       0.00      0.00      0.00         1
#              unauthorised placing on the market       0.00      0.00      0.00         1
#           unauthorised substance ethylene oxide       1.00      1.00      1.00        10
#               unauthorised substance sildenafil       1.00      1.00      1.00         1
#                             undeclared additive       1.00      1.00      1.00         3
#                          undeclared constituent       0.00      0.00      0.00         2
#                                      vibrio spp       1.00      1.00      1.00         1
#                                           virus       1.00      1.00      1.00         1
#                                          walnut       0.83      0.83      0.83         6
#                                          yeasts       1.00      1.00      1.00         1
#
#                                        accuracy                           0.85       997
#                                       macro avg       0.58      0.61      0.59       997
#                                    weighted avg       0.83      0.85      0.83       997

# %% [markdown]
# ## Evaluate the product model

# %% [markdown]
# * Evaluate the model based on the validation data and add predictions to the dev_set.

# %%
# Define a DataLoader for the development set
dev_dataset_product = TextDataset(
    dev_set['cleaned_text'].tolist(),
    dev_set['product_encoded'].tolist(),
    tokenizer,
    max_len=128
)

dev_dataloader_product = DataLoader(dev_dataset_product, batch_size=8, shuffle=False)

# Evaluate the product model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    product_model, dev_dataloader_product, label_encoder_product
)

# Store predictions in the dev_set DataFrame
dev_set['predictions-product'] = predicted_labels
# Out:
#                                                       precision    recall  f1-score   support
#
#                               Catfishes (freshwater)       0.67      1.00      0.80         2
#                                      Dried pork meat       0.00      0.00      0.00         1
#                                Fishes not identified       0.50      0.60      0.55         5
#                  Precooked cooked pork meat products       0.00      0.00      0.00         1
#                                        Veggie Burger       0.00      0.00      0.00         0
#                                      alfalfa sprouts       0.50      1.00      0.67         1
#                                                algae       0.00      0.00      0.00         0
#                                          almond milk       1.00      1.00      1.00         1
#                                      almond products       0.00      0.00      0.00         0
#                                              almonds       0.00      0.00      0.00         0
#                                          apple juice       0.00      0.00      0.00         1
#                                            baby food       0.00      0.00      0.00         0
#                                            baguettes       0.00      0.00      0.00         1
#                                      bakery products       0.50      1.00      0.67         1
#                                           baking mix       1.00      1.00      1.00         1
#                                              baklava       1.00      1.00      1.00         1
#                                                 bars       1.00      0.20      0.33         5
#                                    basil pesto sauce       0.50      1.00      0.67         1
#                                           bean sauce       0.00      0.00      0.00         0
#                                           bean snack       0.00      0.00      0.00         1
#                                         bean sprouts       0.00      0.00      0.00         0
#                                                 beef       1.00      1.00      1.00         1
#                                        beef products       0.00      0.00      0.00         0
#                                                 beer       0.75      1.00      0.86         3
#                                             beverage       0.00      0.00      0.00         0
#                                             biscuits       1.00      0.71      0.83         7
#                                         black pepper       1.00      1.00      1.00         1
#                                          blue cheese       0.00      0.00      0.00         0
#                                        bottled water       0.50      1.00      0.67         2
#                                          brazil nuts       0.00      0.00      0.00         0
#                                                bread       0.33      1.00      0.50         2
#                                            bread mix       0.00      0.00      0.00         1
#                                    breakfast cereals       0.67      1.00      0.80         2
#                                          brie cheese       1.00      1.00      1.00         1
#                                             broccoli       0.00      0.00      0.00         0
#                                             brownies       0.00      0.00      0.00         1
#                               burrito (ready to eat)       0.00      0.00      0.00         1
#                                               butter       0.00      0.00      0.00         1
#                                              cabbage       0.00      0.00      0.00         0
#                                                cakes       0.78      0.88      0.82         8
#                                              candies       0.44      0.67      0.53         6
#                                       canned mussels       0.00      0.00      0.00         1
#                                  carbonated beverage       0.00      0.00      0.00         1
#                                          cauliflower       1.00      1.00      1.00         1
#                                              cbd oil       1.00      1.00      1.00         1
#                                          cereal bars       0.00      0.00      0.00         2
#                                       cheddar cheese       1.00      1.00      1.00         1
#                                               cheese       0.58      1.00      0.74         7
#                          cheese - made from raw milk       0.00      0.00      0.00         1
#                                        cheese spread       0.00      0.00      0.00         0
#                                              chicken       0.00      0.00      0.00         4
#                     chicken and chicken preparations       0.00      0.00      0.00         1
#                               chicken based products       0.38      0.87      0.53        15
#                                       chicken breast       0.20      0.29      0.24         7
#                                        chicken broth       0.00      0.00      0.00         1
#                                 chicken preparations       0.50      0.14      0.22         7
#                            chicken products - frozen       0.00      0.00      0.00         1
#           chilled ready to eat salad and side dishes       0.00      0.00      0.00         1
#                                       chilled salads       0.00      0.00      0.00         1
#                                        chilli powder       1.00      1.00      1.00         1
#                                         chilli sauce       0.00      0.00      0.00         1
#                                            chocolate       0.50      1.00      0.67         1
#                                       chocolate bars       0.33      0.50      0.40         2
#                                      chocolate chips       0.00      0.00      0.00         1
#                              chocolate confectionery       0.00      0.00      0.00         1
#                                    chocolate dessert       0.00      0.00      0.00         1
#                               chocolate drink powder       0.00      0.00      0.00         1
#                                     chocolate mousse       0.00      0.00      0.00         1
#                                   chocolate products       0.33      1.00      0.50         2
#                                           chocolates       0.00      0.00      0.00         1
#                                              chorizo       1.00      1.00      1.00         1
#                                                cider       1.00      1.00      1.00         1
#                                       cinnamon rolls       0.00      0.00      0.00         1
#                                        coconut juice       1.00      1.00      1.00         3
#                                         coconut milk       1.00      1.00      1.00         1
#                                         coffee beans       0.00      0.00      0.00         0
#                                         coffee drink       0.00      0.00      0.00         1
#                                           cola drink       0.00      0.00      0.00         1
#                                       cooked chicken       0.00      0.00      0.00         6
#                                           cooked ham       0.00      0.00      0.00         1
#                                              cookies       0.75      1.00      0.86         9
#                                        cooking sauce       0.00      0.00      0.00         2
#                                            coriander       0.00      0.00      0.00         0
#                                                 corn       0.80      0.67      0.73         6
#                                             crackers       0.67      1.00      0.80         2
#                                         cream cheese       0.00      0.00      0.00         1
#                                  cream chocolate pie       0.00      0.00      0.00         1
#                     crustaceans and products thereof       0.00      0.00      0.00         1
#                                      cured pork meat       0.00      0.00      0.00         1
#                                                curry       0.33      0.50      0.40         2
#                        dark chocolate coated almonds       0.00      0.00      0.00         1
#                                      dark chocolates       0.80      1.00      0.89         4
#                                             desserts       0.20      0.33      0.25         3
#                                   dietary supplement       0.67      0.67      0.67         6
#                                            dip-sauce       0.67      1.00      0.80         2
#                                               donuts       1.00      1.00      1.00         1
#                                             dressing       1.00      1.00      1.00         1
#                                        dried almonds       0.00      0.00      0.00         2
#                                         dried apples       0.00      0.00      0.00         2
#                                       dried apricots       0.67      1.00      0.80         2
#                                      dried beef meat       0.50      1.00      0.67         1
#                                           dried figs       1.00      1.00      1.00         1
#                                         dried fruits       1.00      0.50      0.67         2
#                          dried fruits with chocolate       0.00      0.00      0.00         1
#                                      dried mushrooms       1.00      1.00      1.00         1
#                                          dried plums       0.00      0.00      0.00         3
#                                 dried shrimp noodles       0.00      0.00      0.00         1
#                                            dumplings       0.33      1.00      0.50         1
#                                                 eggs       1.00      1.00      1.00         1
#                              energy and protein bars       0.00      0.00      0.00         1
#                                         energy drink       1.00      1.00      1.00         2
#                                          fajita meal       0.00      0.00      0.00         1
#                                       feed materials       0.00      0.00      0.00         1
#                                  fermented beef meat       0.00      0.00      0.00         1
#                                          feta cheese       1.00      1.00      1.00         2
#                                        fish products       0.00      0.00      0.00         1
#                                     flavoured drinks       0.00      0.00      0.00         1
#                                 flavoured soft drink       0.00      0.00      0.00         1
#                  flavoured whey protein preparations       1.00      1.00      1.00         1
#                                             flaxseed       0.50      1.00      0.67         1
#                                                flour       0.75      1.00      0.86         3
#                                      food supplement       1.00      1.00      1.00         1
#                                      fresh mushrooms       0.67      1.00      0.80         2
#                   fresh processed beef meat products       0.00      0.00      0.00         1
#                                  frozen beef patties       0.00      0.00      0.00         1
#                                       frozen burgers       0.00      0.00      0.00         1
#                                 frozen chicken wings       0.00      0.00      0.00         1
#                           frozen diced chicken roast       0.00      0.00      0.00         1
#                                  frozen fish fillets       0.00      0.00      0.00         1
#                                          frozen peas       1.00      1.00      1.00         1
#                                         frozen pizza       1.00      1.00      1.00         2
#                             frozen pork preparations       0.00      0.00      0.00         1
#                         frozen ready to cook chicken       0.00      0.00      0.00         1
#                                 frozen sausage rolls       0.00      0.00      0.00         1
#                                    frozen vegetables       0.00      0.00      0.00         0
#                                          fruit juice       0.00      0.00      0.00         0
#                                           fruit pies       0.00      0.00      0.00         0
#                                fruits and vegetables       0.00      0.00      0.00         2
#                                        garlic powder       1.00      1.00      1.00         2
#                                        ginger powder       1.00      1.00      1.00         1
#                                        ginger slices       0.00      0.00      0.00         1
#                                    gluten free bread       0.00      0.00      0.00         0
#                                          goat cheese       0.00      0.00      0.00         1
#                              golden raisins/sultanas       0.00      0.00      0.00         0
#                                              granola       0.00      0.00      0.00         0
#                                 grissini breadsticks       0.00      0.00      0.00         1
#                                       ground almonds       0.00      0.00      0.00         1
#                                          ground beef       0.38      0.62      0.48         8
#                                     ground beef meat       0.00      0.00      0.00         1
#                                      ground turmeric       0.00      0.00      0.00         0
#                                                halva       0.00      0.00      0.00         2
#                                                  ham       0.40      1.00      0.57         2
#                                           ham slices       0.00      0.00      0.00         1
#                                            hazelnuts       0.00      0.00      0.00         1
#                                              herring       0.00      0.00      0.00         0
#                                             hot dogs       0.00      0.00      0.00         1
#                                            ice cream       0.95      0.95      0.95        20
#                                       infant formula       1.00      0.50      0.67         2
#                                                  jam       1.00      1.00      1.00         2
#                                              jellies       0.50      1.00      0.67         1
#                                              ketchup       0.00      0.00      0.00         1
#                                                 lamb       0.50      1.00      0.67         1
#                                              lettuce       1.00      1.00      1.00         1
#                                            lollipops       0.00      0.00      0.00         1
#                                       macadamia nuts       0.50      1.00      0.67         2
#                                             mackerel       0.00      0.00      0.00         1
#                                                mango       1.00      1.00      1.00         2
#                                            margarine       0.00      0.00      0.00         1
#                                          marshmalows       0.00      0.00      0.00         1
#                            mashed chickpeas (hummus)       1.00      1.00      1.00         1
#                                massala spice mixture       0.00      0.00      0.00         1
#                                           mayonnaise       1.00      1.00      1.00         1
#          meat and meat products (other than poultry)       0.00      0.00      0.00         1
#                                           meat broth       0.00      0.00      0.00         0
#                                                 milk       0.60      0.75      0.67         4
#                               milk and milk products       0.00      0.00      0.00         1
#                       milk chocolate covered raisins       0.50      1.00      0.67         1
#                                      milk chocolates       1.00      1.00      1.00         1
#                                          milk powder       0.00      0.00      0.00         1
#                                        milk proteins       0.00      0.00      0.00         1
#                                               millet       0.00      0.00      0.00         1
#                                          minced beef       0.00      0.00      0.00         0
#                                          minced pork       0.00      0.00      0.00         1
#                                        mineral water       0.00      0.00      0.00         1
#                                       mineral waters       0.00      0.00      0.00         1
#                          mitragyna speciosa (kratom)       0.00      0.00      0.00         0
#                                           mixed nuts       0.00      0.00      0.00         1
#                                     mixed vegetables       0.00      0.00      0.00         1
#                                           mozzarella       0.00      0.00      0.00         1
#                                    mozzarella cheese       0.00      0.00      0.00         1
#                                               muesli       1.00      1.00      1.00         1
#                                    mung bean sprouts       0.00      0.00      0.00         2
#                                            mushrooms       0.00      0.00      0.00         1
#                                              mussels       0.00      0.00      0.00         0
#                                   non-alcoholic beer       0.00      0.00      0.00         1
#                                              noodles       1.00      0.50      0.67         2
#                                nut and fruit mixture       0.00      0.00      0.00         1
#                                              nut mix       0.00      0.00      0.00         1
#                                             nuts mix       0.00      0.00      0.00         1
#                                                 oats       0.50      0.33      0.40         3
#                                            olive oil       1.00      1.00      1.00         1
#                                               olives       0.00      0.00      0.00         0
#                                               onions       0.50      1.00      0.67         1
#                                         organic tofu       0.00      0.00      0.00         1
#                                 other dairy products       0.00      0.00      0.00         1
#                   other not classified meat products       0.25      0.40      0.31         5
#                                  other types of meat       0.00      0.00      0.00         2
#                                         oyster sauce       0.00      0.00      0.00         1
#                                              oysters       1.00      1.00      1.00         2
#                                             palm oil       1.00      1.00      1.00         1
#                                             pancakes       0.50      1.00      0.67         1
#                                                pasta       0.11      0.25      0.15         4
#                                       pasta products       0.00      0.00      0.00         3
#                                          pasta sauce       0.00      0.00      0.00         2
#                                      pastry products       0.00      0.00      0.00         1
#                                              peaches       1.00      1.00      1.00         1
#                                              peanuts       0.62      0.83      0.71         6
#                                            pepperoni       0.00      0.00      0.00         1
#                            pesto sauce (pesto verde)       0.00      0.00      0.00         1
#                                             pet feed       0.33      1.00      0.50         1
#                                     pickled beetroot       1.00      1.00      1.00         1
#                                      pig meat - pork       0.00      0.00      0.00         3
#                                       pistachio nuts       1.00      1.00      1.00         3
#                                                pizza       1.00      1.00      1.00         1
#                                                poppy       1.00      1.00      1.00         1
#                               pork and beef sausages       0.00      0.00      0.00         1
#                                           pork belly       0.00      0.00      0.00         1
#                                     pork carcass(es)       0.00      0.00      0.00         1
#                                         pork sausage       0.50      0.67      0.57         3
#                                         potato chips       1.00      0.80      0.89         5
#                                         potato salad       1.00      0.50      0.67         4
#                  precooked cooked beef meat products       0.50      1.00      0.67         1
#                                        prepared dish       0.00      0.00      0.00         1
#                                      prepared salads       0.00      0.00      0.00         1
#                                        protein balls       0.00      0.00      0.00         0
#                                          protein bar       0.33      1.00      0.50         2
#                                              pudding       0.00      0.00      0.00         0
#                                                 pâté       0.00      0.00      0.00         1
#                                    quorn preparation       0.00      0.00      0.00         1
#                                          raspberries       0.00      0.00      0.00         0
#                                              ravioli       0.67      0.40      0.50         5
#                                        raw beef meat       0.00      0.00      0.00         0
#                                 raw goat milk cheese       0.00      0.00      0.00         0
#                            ready to eat - cook meals       0.17      0.60      0.26         5
#                                                 rice       0.00      0.00      0.00         0
#                                           rice cakes       0.00      0.00      0.00         1
#                                        rice crackers       0.00      0.00      0.00         0
#                                       ricotta cheese       0.00      0.00      0.00         1
#                                               salads       0.50      1.00      0.67         6
#                                               salami       0.00      0.00      0.00         1
#                                               salmon       1.00      1.00      1.00         8
#                                                 salt       0.00      0.00      0.00         2
#                                           sandwiches       0.67      0.80      0.73         5
#                                                sauce       0.50      0.25      0.33         4
#                                               sauces       0.00      0.00      0.00         0
#                                      sauerkraut meal       0.00      0.00      0.00         1
#                                              sausage       0.67      0.50      0.57         4
#                                     sausage products       0.00      0.00      0.00         1
#                                     seasoned chicken       0.00      0.00      0.00         1
#                                            seasoning       0.43      1.00      0.60         3
#                                           seasonings       0.00      0.00      0.00         1
#                                    semi-hard cheeses       0.00      0.00      0.00         1
#                                               sesame       0.00      0.00      0.00         1
#                                           sesame oil       0.00      0.00      0.00         1
#                                         sesame paste       0.00      0.00      0.00         1
#                                         sesame seeds       0.00      0.00      0.00         1
#                                              shrimps       0.40      1.00      0.57         2
#                                            snack mix       0.17      1.00      0.29         1
#                                     snacks (various)       0.00      0.00      0.00         2
#                                           soda drink       0.00      0.00      0.00         1
#                                                 soup       0.80      1.00      0.89         8
#                                     soy milk product       0.00      0.00      0.00         1
#                                            soy sauce       0.50      1.00      0.67         1
#                                            spice mix       1.00      0.50      0.67         2
#                                          sport drink       0.00      0.00      0.00         1
#                                               spread       0.00      0.00      0.00         0
#                                              spreads       0.00      0.00      0.00         2
#                                         spring rolls       0.67      1.00      0.80         4
#                                              sprouts       0.00      0.00      0.00         1
# structured/textured fish meat products or fish paste       0.00      0.00      0.00         1
#                                       sunflower seed       1.00      1.00      1.00         2
#                                               sweets       0.00      0.00      0.00         3
#                                               tahini       0.50      0.67      0.57         3
#                                tahini (sesame paste)       0.00      0.00      0.00         1
#                                                  tea       0.00      0.00      0.00         0
#                          thermal processed beef meat       1.00      0.33      0.50         3
#                          thermal processed pork meat       0.12      1.00      0.22         1
#                                               toffee       0.00      0.00      0.00         1
#                                                 tofu       0.00      0.00      0.00         0
#                                             tomatoes       1.00      1.00      1.00         1
#                                       tortilla chips       1.00      1.00      1.00         1
#                                                 tuna       1.00      1.00      1.00         1
#                                               turkey       0.00      0.00      0.00         1
#                       turkey and turkey preparations       0.75      0.75      0.75         4
#                                              turnips       1.00      1.00      1.00         1
#                                              unknown       0.00      0.00      0.00        49
#                                        vanilla drink       0.00      0.00      0.00         1
#                                various beef products       0.00      0.00      0.00         1
#                        various chicken meat products       0.00      0.00      0.00         1
#                                       various snacks       0.00      0.00      0.00         1
#                                                 veal       0.33      1.00      0.50         1
#                             vegetable based products       0.00      0.00      0.00         1
#                                vegetable preparation       0.00      0.00      0.00         1
#                                              waffles       1.00      1.00      1.00         1
#                                         whey protein       0.00      0.00      0.00         0
#                                                 wine       1.00      1.00      1.00         3
#                                                wraps       0.33      1.00      0.50         1
#                                              yoghurt       1.00      1.00      1.00         4
#
#                                             accuracy                           0.50       565
#                                            macro avg       0.30      0.36      0.32       565
#                                         weighted avg       0.43      0.50      0.44       565

# %% [markdown]
# * Evaluate the model based on the test data and add predictions to the test_set.

# %%
# Define a DataLoader for the test set
test_dataset_product = TextDataset(
    test_set['cleaned_text'].tolist(),
    test_set['product_encoded'].tolist(),
    tokenizer,
    max_len=128
)

test_dataloader_product = DataLoader(test_dataset_product, batch_size=8, shuffle=False)

# Evaluate the product model
predicted_labels, gold_labels = evaluate_model_with_dataloader(
    product_model, test_dataloader_product, label_encoder_product
)

# Store predictions in the test_set DataFrame
test_set['predictions-product'] = predicted_labels
# Out:
#                                                     precision    recall  f1-score   support
#
#                             Catfishes (freshwater)       0.50      1.00      0.67         3
#                                    Dried pork meat       0.00      0.00      0.00         1
#                              Fishes not identified       0.44      0.88      0.58         8
#                           Not classified pork meat       0.00      0.00      0.00         3
#                Precooked cooked pork meat products       0.00      0.00      0.00         1
#                                      Veggie Burger       0.25      1.00      0.40         1
#                                    alfalfa sprouts       0.00      0.00      0.00         0
#                                              algae       1.00      1.00      1.00         1
#                                     almond kernels       0.00      0.00      0.00         1
#                                    almond products       1.00      1.00      1.00         1
#                                            almonds       0.00      0.00      0.00         0
#                                           amaranth       0.00      0.00      0.00         2
#                                        apple juice       0.00      0.00      0.00         0
#                                             apples       1.00      1.00      1.00         1
#                                    apricot kernels       0.00      0.00      0.00         0
#                                          baby food       0.40      1.00      0.57         2
#                                       baby spinach       0.00      0.00      0.00         0
#                                             bagels       0.00      0.00      0.00         0
#                                    bakery products       0.33      0.25      0.29         4
#                                         baking mix       1.00      0.67      0.80         3
#                                               bars       0.00      0.00      0.00         4
#                                  basil pesto sauce       0.43      1.00      0.60         3
#                                         batter mix       0.00      0.00      0.00         1
#                                         bean sauce       0.00      0.00      0.00         0
#                                       bean sprouts       1.00      1.00      1.00         2
#                                               beef       0.14      0.20      0.17         5
#                                          beef meat       0.00      0.00      0.00         1
#                                      beef products       0.27      0.60      0.38         5
#                                        beef tongue       0.00      0.00      0.00         2
#                                               beer       1.00      1.00      1.00         4
#                                           biscuits       0.50      0.50      0.50         8
#                             bitter apricot kernels       0.00      0.00      0.00         1
#                                       black pepper       1.00      1.00      1.00         1
#                                        blue cheese       0.50      1.00      0.67         1
#                                   blue poppy seeds       0.00      0.00      0.00         1
#                                        blueberries       1.00      1.00      1.00         1
#                                      boneless beef       0.00      0.00      0.00         2
#                              bottled mineral water       0.00      0.00      0.00         0
#                                      bottled water       0.17      1.00      0.29         1
#                                        brazil nuts       0.00      0.00      0.00         0
#                                              bread       0.57      1.00      0.73         8
#                        bread and products therefor       0.00      0.00      0.00         2
#                                  breakfast cereals       0.50      1.00      0.67         4
#                                     brewer's yeast       0.50      1.00      0.67         1
#                                        brie cheese       0.00      0.00      0.00         0
#                                           broccoli       0.38      0.75      0.50         4
#                                           brownies       0.67      0.67      0.67         3
#                                               buns       0.00      0.00      0.00         2
#                             burrito (ready to eat)       1.00      1.00      1.00         1
#                                             butter       0.00      0.00      0.00         2
#                                            cabbage       0.00      0.00      0.00         1
#                                    cake decoration       0.00      0.00      0.00         1
#                                              cakes       0.61      0.79      0.69        14
#                                          camembert       0.00      0.00      0.00         2
#                                            candies       1.00      0.38      0.55         8
#                                        canned corn       0.00      0.00      0.00         1
#                                carbonated beverage       0.00      0.00      0.00         2
#                         carbonated/sparkling water       0.00      0.00      0.00         1
#                                             cashew       0.50      0.67      0.57         3
#                                        cauliflower       0.00      0.00      0.00         1
#                                       cbd products       0.50      1.00      0.67         1
#                                             cereal       0.00      0.00      0.00         1
#                                        cereal bars       0.00      0.00      0.00         2
#                                       cereal drink       0.00      0.00      0.00         1
#                                            cereals       0.00      0.00      0.00         1
#                                     cheddar cheese       0.50      1.00      0.67         2
#                                             cheese       0.35      0.67      0.46         9
#                         cheese (taleggio capriolo)       0.00      0.00      0.00         1
#                                    cheese sausages       0.00      0.00      0.00         1
#                                      cheese spread       0.00      0.00      0.00         0
#                                           cherries       0.00      0.00      0.00         1
#                                         chia seeds       1.00      1.00      1.00         2
#                                            chicken       0.00      0.00      0.00         1
#                   chicken and chicken preparations       0.00      0.00      0.00         1
#                             chicken based products       0.53      0.65      0.58        31
#                                     chicken breast       0.12      0.17      0.14         6
#                              chicken meat products       0.00      0.00      0.00         1
#                                chicken noodle soup       1.00      1.00      1.00         2
#                                        chicken pie       0.00      0.00      0.00         1
#                               chicken preparations       0.00      0.00      0.00         4
#                          chicken products - frozen       0.00      0.00      0.00         1
#                                     chicken slices       0.00      0.00      0.00         1
#                                          chickpeas       1.00      1.00      1.00         1
#                                     chilled salads       0.00      0.00      0.00         1
#                                       chilli paste       1.00      1.00      1.00         1
#                                      chilli powder       0.00      0.00      0.00         0
#                                       chilli sauce       0.50      1.00      0.67         1
#                                          chocolate       0.25      0.33      0.29         3
#                   chocolate and chocolate products       0.00      0.00      0.00         1
#    chocolate and strawberry flavoured cyclone milk       0.00      0.00      0.00         1
#                                     chocolate bars       0.70      1.00      0.82         7
#                                    chocolate chips       0.50      1.00      0.67         2
#                                     chocolate eggs       0.50      0.50      0.50         2
#                                 chocolate products       0.00      0.00      0.00         0
#                                 chocolate truffles       0.00      0.00      0.00         2
#                                   chocolate wafers       0.00      0.00      0.00         0
#                                         chocolates       0.00      0.00      0.00         3
#                                            chorizo       0.33      1.00      0.50         1
#                                    chorizo sausage       0.00      0.00      0.00         1
#                                              cider       1.00      1.00      1.00         2
#                                              clams       1.00      1.00      1.00         1
#                                      coconut drink       0.00      0.00      0.00         0
#                                      coconut juice       0.00      0.00      0.00         1
#                                       coconut milk       0.00      0.00      0.00         1
#                                        coconut oil       1.00      1.00      1.00         1
#                                           coconuts       0.75      0.75      0.75         4
#                                                cod       0.00      0.00      0.00         2
#                                       coffee beans       1.00      0.50      0.67         2
#                                concentrated apples       0.00      0.00      0.00         1
#                                      confectionery       0.00      0.00      0.00         1
#                                     cooked chicken       0.00      0.00      0.00         1
#                                            cookies       0.69      0.79      0.73        14
#                                      cooking sauce       0.00      0.00      0.00         1
#                                          coriander       0.50      0.50      0.50         2
#                                               corn       0.60      1.00      0.75         6
#                                        cottage pie       0.00      0.00      0.00         1
#                                         courgettes       1.00      1.00      1.00         1
#                                              crabs       1.00      1.00      1.00         1
#                                           crackers       0.20      1.00      0.33         1
#                                       cream cheese       0.00      0.00      0.00         1
#                                             crisps       0.00      0.00      0.00         0
#                                         croissants       1.00      1.00      1.00         2
#                                       cumin powder       0.00      0.00      0.00         0
#                                              curry       0.60      1.00      0.75         3
#                                            custard       0.00      0.00      0.00         3
#                                    dark chocolates       0.67      0.86      0.75         7
#                                              dates       0.75      1.00      0.86         3
#                                           desserts       0.40      0.67      0.50         3
#                                 dietary supplement       0.38      0.75      0.50         4
#                                          dip-sauce       1.00      0.60      0.75         5
#                                      dipping sauce       0.00      0.00      0.00         1
#                                           dressing       0.14      1.00      0.25         1
#                                    dressing sauces       0.00      0.00      0.00         1
#                                     dried apricots       0.00      0.00      0.00         0
#                                    dried beef meat       0.40      0.67      0.50         3
#                                  dried cranberries       1.00      1.00      1.00         1
# dried herb powder ashwagandha (withania somnifera)       0.00      0.00      0.00         1
#                                        dried plums       0.00      0.00      0.00         1
#                                dried pork sausages       0.00      0.00      0.00         1
#         dried shitake mushrooms (lentinula edodes)       0.00      0.00      0.00         1
#                               dried shrimp noodles       0.00      0.00      0.00         1
#                          drinking chocolate powder       0.00      0.00      0.00         1
#                                            dry ham       0.00      0.00      0.00         1
#                                               duck       0.50      1.00      0.67         1
#                                          dumplings       0.50      1.00      0.67         2
#                                               eggs       0.73      1.00      0.84         8
#                                       energy drink       0.00      0.00      0.00         2
#                                       fennel seeds       1.00      1.00      1.00         1
#                                        feta cheese       1.00      0.29      0.44         7
#                             fish and fish products       0.00      0.00      0.00         2
#                                      fish products       0.00      0.00      0.00         2
#                             flavoured potato chips       0.00      0.00      0.00         3
#                flavoured whey protein preparations       0.00      0.00      0.00         0
#                                           flavours       0.00      0.00      0.00         1
#                                           flaxseed       0.00      0.00      0.00         0
#                                              flour       0.67      0.67      0.67         3
#                                    food supplement       0.20      0.33      0.25         3
#                                    fresh mushrooms       0.50      1.00      0.67         2
#                 fresh processed beef meat products       0.00      0.00      0.00         1
#                                frozen beef patties       0.00      0.00      0.00         2
#                               frozen beef products       0.00      0.00      0.00         1
#                                    frozen broccoli       0.50      1.00      0.67         1
#                                     frozen burgers       0.00      0.00      0.00         1
#                                     frozen chicken       0.00      0.00      0.00         1
#                         frozen dumplings with pork       0.00      0.00      0.00         1
#                               frozen fish products       0.00      0.00      0.00         1
#                                        frozen peas       0.25      1.00      0.40         1
#                                         frozen pie       0.00      0.00      0.00         2
#                                       frozen pizza       0.67      0.67      0.67         3
#                           frozen pork preparations       0.00      0.00      0.00         1
#                            frozen poultry products       0.00      0.00      0.00         1
#                       frozen ready to cook chicken       0.00      0.00      0.00         1
#                               frozen sausage rolls       0.00      0.00      0.00         1
#                                     frozen seafood       0.00      0.00      0.00         1
#                                frozen spring rolls       0.00      0.00      0.00         1
#                                  frozen vegetables       0.00      0.00      0.00         2
#                              frozen vegetables mix       0.00      0.00      0.00         2
#                           frozen vegetarian cutlet       0.00      0.00      0.00         1
#                                         fruit bars       0.00      0.00      0.00         2
#                                        fruit juice       0.00      0.00      0.00         1
#                                         fruit pies       0.00      0.00      0.00         1
#                                       fruit snacks       0.00      0.00      0.00         1
#                              fruits and vegetables       0.00      0.00      0.00         1
#                                      garlic powder       1.00      1.00      1.00         2
#                                  gluten free bread       0.00      0.00      0.00         0
#                                        goat cheese       0.00      0.00      0.00         5
#                            golden raisins/sultanas       0.75      0.50      0.60         6
#                                  gorgonzola cheese       1.00      1.00      1.00         1
#                                            granola       0.50      1.00      0.67         1
#                                          gravy mix       1.00      1.00      1.00         1
#                                        green pesto       0.00      0.00      0.00         3
#                               grissini breadsticks       0.00      0.00      0.00         1
#                                     ground almonds       0.00      0.00      0.00         2
#                                        ground beef       0.67      0.89      0.76         9
#                                    halloumi cheese       0.00      0.00      0.00         0
#                                              halva       0.00      0.00      0.00         1
#                                                ham       0.62      1.00      0.77         5
#                                         ham slices       0.00      0.00      0.00         1
#                                          hazelnuts       0.00      0.00      0.00         4
#                                hemp protein powder       0.00      0.00      0.00         0
#                                         herbal tea       0.00      0.00      0.00         1
#                                            herring       0.20      1.00      0.33         1
#                                              honey       0.00      0.00      0.00         1
#                                horseradish in jars       1.00      1.00      1.00         1
#                                             horses       0.00      0.00      0.00         1
#                                   hot dog sausages       0.00      0.00      0.00         1
#                                           hot dogs       0.00      0.00      0.00         2
#                                          ice cream       0.89      0.98      0.93        41
#                                     infant formula       1.00      1.00      1.00         3
#                                     instant coffee       1.00      1.00      1.00         1
#                                                jam       0.00      0.00      0.00         0
#                                            jellies       0.86      1.00      0.92         6
#                                     jerky products       0.00      0.00      0.00         1
#                                               kale       1.00      1.00      1.00         1
#                                               lamb       0.67      1.00      0.80         2
#                                            lentils       1.00      1.00      1.00         1
#                                              limes       0.00      0.00      0.00         1
#                                     macadamia nuts       0.67      1.00      0.80         2
#                                              maize       0.00      0.00      0.00         2
#                                              mango       1.00      1.00      1.00         2
#                                          margarine       0.00      0.00      0.00         2
#                             marinated chicken meat       0.00      0.00      0.00         1
#                                        marshmalows       1.00      1.00      1.00         1
#                          mashed chickpeas (hummus)       0.67      1.00      0.80         4
#        meat and meat products (other than poultry)       0.00      0.00      0.00         1
#                                  meat preparations       0.00      0.00      0.00         1
#                                           meatloaf       1.00      1.00      1.00         1
#                mechanically separated chicken meat       0.00      0.00      0.00         1
#                                        melon seeds       1.00      1.00      1.00         1
#                                             melons       0.00      0.00      0.00         1
#                                               milk       0.56      1.00      0.71         5
#                     milk chocolate covered raisins       0.29      1.00      0.44         2
#                                    milk chocolates       1.00      0.75      0.86         4
#                                        milk powder       0.00      0.00      0.00         1
#                                      milk products       0.00      0.00      0.00         1
#                                      milk proteins       0.00      0.00      0.00         2
#                                        minced beef       1.00      1.00      1.00         1
#                                      mineral water       0.00      0.00      0.00         1
#                        mitragyna speciosa (kratom)       1.00      1.00      1.00         3
#                                         mixed nuts       0.00      0.00      0.00         1
#                                        mixed salad       0.00      0.00      0.00         2
#                                   mixed vegetables       0.00      0.00      0.00         1
#                                             muesli       0.00      0.00      0.00         0
#                                            muffins       0.60      1.00      0.75         3
#                      multi vitamin food supplement       0.00      0.00      0.00         1
#                                          mushrooms       0.00      0.00      0.00         2
#                                            mussels       0.00      0.00      0.00         0
#                                             noodle       0.00      0.00      0.00         3
#                                            noodles       0.60      0.75      0.67         4
#                              nut and fruit mixture       0.00      0.00      0.00         1
#                                            nut mix       0.00      0.00      0.00         1
#                                    nutrition shake       0.00      0.00      0.00         1
#                                               nuts       0.00      0.00      0.00         2
#                       nuts, nut products and seeds       0.00      0.00      0.00         1
#                                               oats       1.00      1.00      1.00         1
#                                          olive oil       0.50      1.00      0.67         1
#                                             olives       0.75      1.00      0.86         3
#                                             onions       0.50      1.00      0.67         2
#                                       orange juice       0.00      0.00      0.00         1
#                               other dairy products       0.25      1.00      0.40         2
#                 other not classified meat products       0.39      0.50      0.44        14
#                                other types of meat       1.00      0.25      0.40         4
#                                            oysters       1.00      1.00      1.00         4
#                                           palm oil       1.00      1.00      1.00         2
#                                           pancakes       0.00      0.00      0.00         1
#                                              pasta       0.00      0.00      0.00         1
#                                        pasta salad       1.00      1.00      1.00         1
#                                        pasta sauce       0.00      0.00      0.00         3
#                                             pastry       0.00      0.00      0.00         1
#                                    pastry products       0.00      0.00      0.00         0
#                                         pea shoots       1.00      1.00      1.00         1
#                                            peanuts       0.67      1.00      0.80         8
#                                          pepperoni       0.00      0.00      0.00         1
#                                           pet feed       1.00      1.00      1.00         2
#                                   pickled cucumber       0.00      0.00      0.00         0
#                                    pig meat - pork       0.00      0.00      0.00         3
#                                     pistachio nuts       0.88      1.00      0.93         7
#                                              pizza       0.00      0.00      0.00         0
#                    plum bread &amp; butter pudding       0.00      0.00      0.00         1
#                                              poppy       0.50      1.00      0.67         1
#                                   pork preparation       0.00      0.00      0.00         8
#                                       pork sausage       0.50      0.83      0.62         6
#                                      pork shoulder       0.00      0.00      0.00         1
#                                       potato chips       0.60      0.75      0.67         8
#                                  potato croquettes       0.00      0.00      0.00         1
#                                       potato salad       1.00      1.00      1.00         2
#                                           potatoes       0.25      1.00      0.40         1
#                                            poultry       0.00      0.00      0.00         1
#             poultry meat and poultry meat products       0.00      0.00      0.00         1
#                                             prawns       1.00      1.00      1.00         3
#                precooked cooked beef meat products       0.00      0.00      0.00         0
#                                      prepared dish       0.00      0.00      0.00         2
#                                    prepared dishes       0.00      0.00      0.00         1
#                         prepared dishes and snacks       0.00      0.00      0.00         1
#                                    prepared salads       0.00      0.00      0.00         2
#                                      pretzel stick       0.50      1.00      0.67         1
#                                           pretzels       0.00      0.00      0.00         1
#                          probiotic food supplement       0.00      0.00      0.00         0
#                                      protein balls       0.00      0.00      0.00         1
#                                        protein bar       0.67      1.00      0.80         4
#                                      protein drink       0.00      0.00      0.00         0
#                                     protein powder       0.00      0.00      0.00         1
#                                               pâté       1.00      1.00      1.00         1
#                                  quorn preparation       0.00      0.00      0.00         1
#                                        raspberries       0.00      0.00      0.00         0
#                                            ravioli       1.00      0.75      0.86         4
#                                      raw beef meat       0.75      1.00      0.86         6
#                               raw goat milk cheese       0.00      0.00      0.00         0
#                                           raw milk       0.00      0.00      0.00         1
#                          raw milk cheese reblochon       0.00      0.00      0.00         1
#       raw pork meat and raw pork meat preparations       0.00      0.00      0.00         1
#                          ready to eat - cook meals       0.30      0.37      0.33        19
#                          ready to eat meat product       0.00      0.00      0.00         1
#                                               rice       0.00      0.00      0.00         1
#                                         rice cakes       1.00      1.00      1.00         1
#                           rice cereal for children       0.00      0.00      0.00         1
#                                      rice crackers       0.00      0.00      0.00         1
#                                          rice meal       0.00      0.00      0.00         1
#                                        rice sticks       0.00      0.00      0.00         1
#                                     ricotta cheese       0.00      0.00      0.00         1
#                                     salad dressing       0.00      0.00      0.00         4
#                                             salads       0.41      0.78      0.54         9
#                                             salami       0.25      1.00      0.40         1
#                                             salmon       1.00      0.91      0.95        11
#                                               salt       1.00      1.00      1.00         1
#                                   sandwich filling       0.00      0.00      0.00         1
#                                         sandwiches       0.80      1.00      0.89         8
#                                           sardines       1.00      1.00      1.00         1
#                                              sauce       1.00      1.00      1.00         3
#                                             sauces       0.50      0.67      0.57         3
#                                            sausage       0.16      0.75      0.26         4
#                                   sausage products       0.40      0.50      0.44         4
#                                            seafood       0.00      0.00      0.00         2
#                                   seafood products       0.00      0.00      0.00         1
#                                          seasoning       0.20      1.00      0.33         1
#                                      seasoning mix       0.00      0.00      0.00         1
#                                             sesame       1.00      1.00      1.00         1
#                                       sesame seeds       1.00      1.00      1.00         2
#                                            shrimps       0.50      0.80      0.62         5
#                                         sliced ham       0.00      0.00      0.00         2
#                                     smoked sausage       0.00      0.00      0.00         3
#                                           smoothie       0.00      0.00      0.00         1
#                                          snack mix       0.38      0.75      0.50         4
#                                   snacks (various)       0.33      0.40      0.36         5
#                                soft ripened cheese       0.00      0.00      0.00         1
#                                            sorbets       0.00      0.00      0.00         1
#                                               soup       0.86      1.00      0.92        12
#                                          soy sauce       1.00      1.00      1.00         1
#                                            soybean       1.00      0.50      0.67         2
#                                          spice mix       0.25      1.00      0.40         1
#                                             spices       0.00      0.00      0.00         1
#                                            spinach       0.00      0.00      0.00         2
#                                            spirits       0.00      0.00      0.00         0
#                                        sport drink       0.00      0.00      0.00         0
#                                             spread       0.50      1.00      0.67         1
#                                            spreads       0.00      0.00      0.00         1
#                                       spring rolls       0.00      0.00      0.00         0
#                                       spring water       0.00      0.00      0.00         1
#                                          sprinkles       0.00      0.00      0.00         1
#                                            sprouts       0.00      0.00      0.00         1
#                                              squid       0.00      0.00      0.00         1
#                                             starch       0.00      0.00      0.00         1
#                                              sugar       1.00      1.00      1.00         1
#                                           sultanas       0.00      0.00      0.00         1
#                                     sunflower seed       0.50      0.75      0.60         4
#                                         sweeteners       1.00      1.00      1.00         1
#                                             sweets       0.00      0.00      0.00         2
#                                             tahini       1.00      1.00      1.00         2
#                                                tea       0.40      1.00      0.57         2
#                               testosterone booster       0.00      0.00      0.00         1
#                        thermal processed beef meat       0.50      1.00      0.67         4
#                        thermal processed pork meat       0.17      0.36      0.23        11
#                                            tilapia       0.00      0.00      0.00         1
#                                               tofu       0.00      0.00      0.00         3
#                                       tomato sauce       0.00      0.00      0.00         1
#                                           tomatoes       0.00      0.00      0.00         1
#                                           tortilla       0.00      0.00      0.00         0
#                                     tortilla chips       1.00      1.00      1.00         2
#                                             trouts       1.00      1.00      1.00         1
#                                               tuna       0.75      1.00      0.86         3
#                    turbot flatfish (psetta maxima)       0.00      0.00      0.00         1
#                                             turkey       0.00      0.00      0.00         1
#                     turkey and turkey preparations       0.42      0.71      0.53         7
#                              turkey based products       0.00      0.00      0.00         4
#                                            unknown       0.00      0.00      0.00        84
#                            various bakery products       0.00      0.00      0.00         1
#                              various beef products       0.00      0.00      0.00         1
#            various chilled or frozen pork products       0.00      0.00      0.00         1
#                              various meat products       0.00      0.00      0.00         1
#                                               veal       0.00      0.00      0.00         0
#                               veal meat and offals       0.00      0.00      0.00         1
#                           vegetable based products       0.00      0.00      0.00         2
#                                   vegetable burger       0.00      0.00      0.00         1
#                       vegetable ready to eat meals       0.00      0.00      0.00         1
#                                         vegetables       0.00      0.00      0.00         1
#                                           vitamins       0.00      0.00      0.00         1
#                                              vodka       0.00      0.00      0.00         1
#                                             wafers       0.00      0.00      0.00         1
#                                            waffles       0.00      0.00      0.00         1
#                                            walnuts       1.00      1.00      1.00         1
#                                    white chocolate       0.00      0.00      0.00         1
#                                               wine       1.00      1.00      1.00         9
#                                              wraps       1.00      0.75      0.86         4
#                                            yoghurt       0.88      1.00      0.93         7
#                                     yogurt raisins       0.00      0.00      0.00         2
#
#                                           accuracy                           0.51       997
#                                          macro avg       0.29      0.36      0.31       997
#                                       weighted avg       0.42      0.51      0.44       997

# %% [markdown]
# # Compute final scores

# %% [markdown]
# * Compute and print the final score based on the validation data.

# %%
score_st1 = compute_score(
    dev_set['hazard-category'], dev_set['product-category'],
    dev_set['predictions-hazard-category'], dev_set['predictions-product-category']
)
print(f"Score Sub-Task 1: {score_st1:.3f}")

score_st2 = compute_score(
    dev_set['hazard'], dev_set['product'],
    dev_set['predictions-hazard'], dev_set['predictions-product'])
print(f"Score Sub-Task 2: {score_st2:.3f}")
# Out:
# Score Sub-Task 1: 0.783
# Score Sub-Task 2: 0.459

# %% [markdown]
# * Compute and print the final score based on the test data.

# %%
score_st1 = compute_score(
    test_set['hazard-category'], test_set['product-category'],
    test_set['predictions-hazard-category'], test_set['predictions-product-category']
)
print(f"Score Sub-Task 1: {score_st1:.3f}")

score_st2 = compute_score(
    test_set['hazard'], test_set['product'],
    test_set['predictions-hazard'], test_set['predictions-product'])
print(f"Score Sub-Task 2: {score_st2:.3f}")
# Out:
# Score Sub-Task 1: 0.759
# Score Sub-Task 2: 0.426

# %% [markdown]
# # Predict Test Set

# %% [markdown]
# * Create a df to store the predictions.

# %%
predictions = pd.DataFrame()

# %% [markdown]
# * Predict the ST1 test data and store them in the predictions df.

# %%
predictions['hazard-category'] = predict(test_set.title.to_list(), hazard_category_model, label_encoder_hazard_category, tokenizer)
predictions['product-category'] = predict(test_set.title.to_list(), product_category_model, label_encoder_product_category, tokenizer)

# %% [markdown]
# * Predict the ST2 test data and store them in the predictions df.

# %%
predictions['hazard'] = predict(test_set.title.to_list(), hazard_model, label_encoder_hazard, tokenizer)
predictions['product'] = predict(test_set.title.to_list(), product_model, label_encoder_product, tokenizer)

# %% [markdown]
# * Create a new folder named 'submission' if it doesn't already exist.
# * Save predictions to 'submission.csv' inside the 'submission' folder and zip it.

# %%
# Save predictions to a new folder
os.makedirs('./submission/', exist_ok=True)
predictions.to_csv('./submission/submission.csv')

# Zip the folder
make_archive('./submission', 'zip', './submission')
# Out:
# '/home/ec2-user/SageMaker/submission.zip'
